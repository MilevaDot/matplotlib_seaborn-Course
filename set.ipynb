# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.barplot(x = ['A', 'B', 'C'], y = [1, 3, 2])
plt.show()

# %% [markdown]
# .set sirve para cambiar algunos parámetros, por ejemplo, el estilo. Para el ejemplo usaremos el estilo darkgrid:

# %%
sns.set(style='darkgrid')
sns.barplot(x = ['A', 'B', 'C'], y = [1, 3, 2])
plt.show()

# %% [markdown]
# O también podemos usar el estilo dark

# %%
sns.set(style='dark')
sns.barplot(x = ['A', 'B', 'C'], y = [1, 3, 2])
plt.show()

# %% [markdown]
# Se puede cambiar el atributo palette que modifica los colores de las barras:

# %%
sns.set(style='dark', palette = 'muted')
sns.barplot(x = ['A', 'B', 'C'], y = [1, 3, 2])
plt.show()

# %%
sns.set(style='dark', palette = 'deep')
sns.barplot(x = ['A', 'B', 'C'], y = [1, 3, 2])
plt.show()

# %%
sns.set(style='dark', palette = 'dark')
sns.barplot(x = ['A', 'B', 'C'], y = [1, 3, 2])
plt.show()

# %% [markdown]
# Podemos cambiar la fuente y la escala de la fuente que usamos:

# %%
sns.set(style='dark', palette = 'dark', font='Verdana', font_scale=1)
sns.barplot(x = ['A', 'B', 'C'], y = [1, 3, 2])
plt.show()

# %% [markdown]
# El link a la documentación de set:
#
# https://seaborn.pydata.org/generated/seaborn.set_theme.html#seaborn.set_theme
#
# El link a la documentación de los colores, algo adicional:
#
# https://seaborn.pydata.org/generated/seaborn.set_theme.html#seaborn.set_theme

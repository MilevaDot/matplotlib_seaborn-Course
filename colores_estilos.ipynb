# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 5, 11)

# %% [markdown]
# Vamos a imprimir los estilos sobre los que podemos trabajar por default:

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %% [markdown]
# Escojamos uno de los estilos:

# %%
plt.style.use('dark_background')

# %% [markdown]
# Ahora que escogimos uno de los estilos, los lienzos y las fuentes se verán distintas:

# %%
fig, ax = plt.subplots(figsize=(8,8))

ax.plot(x, x+1, 'r')
ax.plot(x, x+2, 'b')
ax.plot(x, x+3, 'y')
ax.plot(x, x+4, 'g')
ax.plot(x, x+5, 'c')

# %% [markdown]
# Ahora haremos modificaciones del tipo Matlab. Es decir, los colores y la forma de la gráfica entre comillas simples:

# %%
fig, ax = plt.subplots(figsize=(8,8))

ax.plot(x, x+1, 'r--')
ax.plot(x, x+2, 'b-')
ax.plot(x, x+3, 'y.-')
ax.plot(x, x+4, 'go:')
plt.show()

# %% [markdown]
# Ahora, la forma de Pyplot. Es decir, podemos acceder a estas características de manera explícita y más customizable. Incluos alpha nos permite entrar a la no transparencia de la gráfica. Y linewidth nos permite cambiar el grosor de las gráficas. linestyle permite modificar el tipo de linea que se verá. marker indicar qué deben aparecer en los puntos. markersize indica el tamaño del punto. markerfacecolor indica el color del punto:

# %%
fig, ax = plt.subplots(figsize=(8,8))

ax.plot(x, x+1, color='green', alpha = 0.5, linewidth=5, linestyle='-', marker= 'o', markersize = 10, markerfacecolor='#CCFFCC')
ax.plot(x, x+2, color='blue', linewidth=8, linestyle='--', marker= 'x')
ax.plot(x, x+3, color='#66FF66', linewidth=3, linestyle='dashed', marker= 'v')
ax.plot(x, x+4, color='#CCFFCC', linewidth=2, linestyle=':', marker= 'P')
plt.show()
